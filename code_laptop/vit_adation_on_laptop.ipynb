# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms, utils
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
import numpy as np

# %%
# Will be in the data set
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),transforms.Resize([224,224], antialias=True)])

train_dataset = datasets.ImageFolder(root='../data/training_set', transform=transform)
test_dataset = datasets.ImageFolder(root='../data/test_set', transform=transform)

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 8005
# 2023

# %%
# Partition data set
train_db, val_db = torch.utils.data.random_split(train_dataset, [7000, 1005])

train_loader = DataLoader(train_db, batch_size=32, shuffle=True)
val_loader = DataLoader(val_db, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
# Fine-tuning model structure
class MyViT(nn.Module):
    def __init__(self, model, target_size):
        super(MyViT, self).__init__()
        self.model = model

        for param in self.model.parameters():
          param.requires_grad = False

        n_features = self.model.head.in_features
        # Change the head and change the number of categories
        self.model.head = nn.Linear(n_features, target_size)

    def forward(self, x):
        x = self.model(x)
        return x

# %%
# !pip install timm
# Out:
# Requirement already satisfied: timm in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (0.9.12)
# Requirement already satisfied: torch>=1.7 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from timm) (2.1.0+cu118)
# Requirement already satisfied: torchvision in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from timm) (0.16.0)
# Requirement already satisfied: pyyaml in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from timm) (0.19.4)
# Requirement already satisfied: safetensors in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from timm) (0.4.1)
# Requirement already satisfied: filelock in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7->timm) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7->timm) (4.8.0)
# Requirement already satisfied: sympy in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7->timm) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7->timm) (2023.10.0)
# Requirement already satisfied: requests in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub->timm) (23.2)
# Requirement already satisfied: numpy in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torchvision->timm) (1.26.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torchvision->timm) (10.1.0)
# Requirement already satisfied: colorama in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->timm) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub->timm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub->timm) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub->timm) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.7->timm) (1.3.0)

# %%
# Preparation training
device = torch.device("cuda")
model = torch.hub.load('facebookresearch/deit:main','deit_tiny_patch16_224', pretrained=True)

net_base = MyViT(model,2).to(device=device, dtype=torch.float32)
optimizer = torch.optim.Adam([{'params': net_base.model.head.parameters()}], lr=0.001, weight_decay=1e-8)
criterion = nn.CrossEntropyLoss()
# Out:
# Using cache found in C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main
# C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main\models.py:62: UserWarning: Overwriting deit_tiny_patch16_224 in registry with models.deit_tiny_patch16_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main\models.py:77: UserWarning: Overwriting deit_small_patch16_224 in registry with models.deit_small_patch16_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main\models.py:92: UserWarning: Overwriting deit_base_patch16_224 in registry with models.deit_base_patch16_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main\models.py:107: UserWarning: Overwriting deit_tiny_distilled_patch16_224 in registry with models.deit_tiny_distilled_patch16_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main\models.py:122: UserWarning: Overwriting deit_small_distilled_patch16_224 in registry with models.deit_small_distilled_patch16_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main\models.py:137: UserWarning: Overwriting deit_base_distilled_patch16_224 in registry with models.deit_base_distilled_patch16_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main\models.py:152: UserWarning: Overwriting deit_base_patch16_384 in registry with models.deit_base_patch16_384. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# C:\Users\Mayn/.cache\torch\hub\facebookresearch_deit_main\models.py:167: UserWarning: Overwriting deit_base_distilled_patch16_384 in registry with models.deit_base_distilled_patch16_384. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model

# %%
MinTrainLoss=999
epochs=5

val_loss = []
val_acc=[]

for epoch in range(1, epochs+1):
    total_train_loss = []
    total_val_loss = []

    # Train
    net_base.train()
    for input_img, label in train_loader:
        input_img = input_img.cuda()
        label = label.cuda()
        optimizer.zero_grad()

        pred_img = net_base(input_img)
        loss = criterion(pred_img, label)
        loss.backward()
        optimizer.step()

    # Verify
    net_base.eval()
    current = 0
    with torch.no_grad():
        for val_img, val_label in val_loader:
            val_img = val_img.cuda()
            val_label = val_label.cuda()

            pred = net_base(val_img)
            total_val_loss.append(criterion(pred, val_label).item())
            current += (pred.argmax(1)==val_label).type(torch.float).sum().item()

    val_loss.append(np.mean(total_val_loss))
    val_acc.append(current/1005*100)

    print("epochs[%3d/%3d] val_loss: %.5f, val_acc: %.3f"%(epoch, epochs, val_loss[-1],val_acc[-1]))
# Out:
# epochs[  1/  5] val_loss: 0.04823, val_acc: 98.607
# epochs[  2/  5] val_loss: 0.03865, val_acc: 98.905
# epochs[  3/  5] val_loss: 0.03684, val_acc: 98.905
# epochs[  4/  5] val_loss: 0.03598, val_acc: 98.905
# epochs[  5/  5] val_loss: 0.03419, val_acc: 98.905

# %%
net_base.eval()
current = 0
total_test_loss = []
with torch.no_grad():
    for test_img, test_label in test_loader:
        test_img = test_img.cuda()
        test_label = test_label.cuda()

        pred = net_base(test_img)
        total_test_loss.append(criterion(pred, test_label).item())
        current += (pred.argmax(1)==test_label).type(torch.float).sum().item()

print("testdataset test_loss: %.5f, test_acc: %.3f"%(np.mean(total_val_loss), current/2023*100))
# Out:
# testdataset test_loss: 0.03419, test_acc: 98.764

# %% [markdown]
# ## Attention visualization

# %%
# !pip install grad-cam
# Out:
# Requirement already satisfied: grad-cam in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (1.4.8)
# Requirement already satisfied: numpy in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (1.26.2)
# Requirement already satisfied: Pillow in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (10.1.0)
# Requirement already satisfied: torch>=1.7.1 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.8.2 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (0.16.0)
# Requirement already satisfied: ttach in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (0.0.3)
# Requirement already satisfied: tqdm in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (4.66.1)
# Requirement already satisfied: opencv-python in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (4.8.1.78)
# Requirement already satisfied: matplotlib in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (3.8.2)
# Requirement already satisfied: scikit-learn in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from grad-cam) (1.3.2)
# Requirement already satisfied: filelock in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7.1->grad-cam) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7.1->grad-cam) (4.8.0)
# Requirement already satisfied: sympy in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7.1->grad-cam) (1.12)
# Requirement already satisfied: networkx in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7.1->grad-cam) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7.1->grad-cam) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.7.1->grad-cam) (2023.10.0)
# Requirement already satisfied: requests in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from torchvision>=0.8.2->grad-cam) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->grad-cam) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->grad-cam) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->grad-cam) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->grad-cam) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->grad-cam) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->grad-cam) (2.8.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->grad-cam) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->grad-cam) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->grad-cam) (3.2.0)
# Requirement already satisfied: colorama in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from tqdm->grad-cam) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.7.1->grad-cam) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision>=0.8.2->grad-cam) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision>=0.8.2->grad-cam) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision>=0.8.2->grad-cam) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision>=0.8.2->grad-cam) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mayn\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.7.1->grad-cam) (1.3.0)

# %%
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam import GuidedBackpropReLUModel
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image
from pytorch_grad_cam.ablation_layer import AblationLayerVit

import cv2

# %%
def reshape_transform(tensor, height=14, width=14):
    # Drop cls token
    result = tensor[:,1:,:].reshape(tensor.size(0), height, width, tensor.size(2))
    result = result.transpose(2, 3).transpose(1, 2)
    print("result:",result.shape)

    return result

# %%
# Preparing the data
transform = transforms.Compose([transforms.ToTensor(),transforms.Resize([224,224], antialias=True)])

dataset = datasets.ImageFolder(root='../data/test_set',transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
model = net_base.model.cuda()

for param in model.parameters():
  param.requires_grad = True

# Create a GradCAM object
cam = GradCAM(model = model,target_layers=[model.blocks[-1].norm1], use_cuda=True, reshape_transform = reshape_transform)

# %%
# Take the picture
rgb_img = next(iter(dataloader))[0][0]
img = rgb_img.numpy()
img = np.transpose(img,(1,2,0))
img = img.astype(np.float32)
img = (img - np.min(img)) / (np.max(img) - np.min(img))
input_tensor = preprocess_image(img, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
input_tensor = input_tensor.cuda()

# %%
# computation grad-cam
target_category = None
grayscale_cam = cam(input_tensor = input_tensor, targets=target_category)
grayscale_cam = grayscale_cam[0, :]


# The output of grad-cam is superimposed on the original image
visualization = show_cam_on_image(img, grayscale_cam)

cv2.imwrite('cam1.jpg', visualization)
# Out:
# result: torch.Size([1, 192, 14, 14])
# result: torch.Size([1, 192, 14, 14])
# True

# %%
plt.imshow(img)

# %%
plt.imshow(visualization)
